# %% [markdown]
# # **Check** **Resource**

# %%
# !nvidia-smi
# Out:
# Sun May 11 21:21:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
#!pip uninstall "numpy<2.0"
# !pip uninstall numpy
# Out:
# Found existing installation: numpy 2.2.5
# Uninstalling numpy-2.2.5:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/numpy-config
#     /usr/local/lib/python3.11/dist-packages/numpy-2.2.5.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libgfortran-040039e1-0352e75f.so.5.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libquadmath-96973f99-934c22de.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libscipy_openblas64_-6bb31eeb.so
#     /usr/local/lib/python3.11/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-2.2.5

# %% [markdown]
# # **Install YOLOV8**

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-670904ac7724> in <cell line: 0>()
#       6 display.clear_output()
#       7
# ----> 8 import ultralytics
#       9 ultralytics.checks()
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/__init__.py in <module>
#       3 __version__ = '8.0.196'
#       4
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/rtdetr/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ...

# %% [markdown]
# # **Exporting Dataset**

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f9b4f2298fcf> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 from IPython.display import display, Image
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/__init__.py in <module>
#       3 __version__ = '8.0.196'
#       4
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/rtdetr/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ...

# %%
# !mkdir -p $HOME/datasets
# %cd $HOME/datasets


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fX9vAEhNs2EBYFj9GmEa")
project = rf.workspace("xtron135").project("dtmx-fcscu")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Barcode-Detection--1 in yolov8:: 100%|██████████| 2218/2218 [00:00<00:00, 5240.22it/s]

# %% [markdown]
# # **Custom** **Training**

# %%
# %cd /content/datasets
# !pip install torch==2.1.2 torchvision --upgrade



# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/Barcode-Detection--1/data.yaml epochs=100 batch=16 imgsz=640 plots=True
#!yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 batch=16 imgsz=640 plots=True amp=True lr0=0.01 augment=True save_period=10 patience=5
# Out:
# /content/datasets
# ...
#   Using cached torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# ...
# INFO: pip is looking at multiple versions of torchvision to determine which version is compatible with other requirements. This could take a while.
#   Using cached torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
#   Using cached torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
#   Using cached torchvision-0.20.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
#   Using cached torchvision-0.19.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.0 kB)
#   Using cached torchvision-0.19.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.0 kB)
#   Using cached torchvision-0.18.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
#   Using cached torchvision-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# ...

# %% [markdown]
# # **Confusion Matrix**

# %%
# !ls /content/datasets/runs/detect/train2
# Out:
# args.yaml					    train_batch1.jpg
# confusion_matrix_normalized.png			    train_batch2.jpg
# confusion_matrix.png				    train_batch4950.jpg
# events.out.tfevents.1746774968.775a5a0b0e01.4213.0  train_batch4951.jpg
# F1_curve.png					    train_batch4952.jpg
# labels_correlogram.jpg				    val_batch0_labels.jpg
# labels.jpg					    val_batch0_pred.jpg
# P_curve.png					    val_batch1_labels.jpg
# PR_curve.png					    val_batch1_pred.jpg
# R_curve.png					    val_batch2_labels.jpg
# results.csv					    val_batch2_pred.jpg
# results.png					    weights
# train_batch0.jpg

# %%
# %cd
Image(filename=f'/content/datasets/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /root
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b1623698695a> in <cell line: 0>()
#       1 get_ipython().run_line_magic('cd', '')
# ----> 2 Image(filename=f'/content/datasets/runs/detect/train2/confusion_matrix.png', width=600)
#
# NameError: name 'Image' is not defined

# %% [markdown]
# # **Model Validation**

# %%
# %cd

# !yolo task=detect mode=val model=/content/datasets/runs/detect/train2/weights/best.pt data=/content/datasets/Barcode-Detection--1/data.yaml
# Out:
# /root
# Ultralytics YOLOv8.0.196 🚀 Python-3.11.12 torch-2.1.2+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/datasets/Barcode-Detection--1/valid/labels.cache... 178 images, 0 backgrounds, 0 corrupt: 100% 178/178 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:03<00:00,  3.02it/s]
#                    all        178        474      0.938      0.764      0.795      0.648
#                      0        178        413      0.959      0.963      0.989      0.842
#                     QR        178         50          1      0.976      0.995      0.654
#                    box        178          2          1          0          0          0
#             datamatrix        178          2      0.729          1      0.995      0.822
#                 qrcode        178          7          1      0.883      0.995      0.922
# ...

# %% [markdown]
# # **Inference**

# %%
# !yolo task=detect mode=predict model=/content/datasets/runs/detect/train2/weights/best.pt conf=0.25 source=/content/datasets/Barcode-Detection--1/test/images save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.11.12 torch-2.1.2+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/59 /content/datasets/Barcode-Detection--1/test/images/2-0006934349-0_jpeg.rf.8d82a1132c50df43339df1edc9730508.jpg: 256x640 1 QR, 68.5ms
# image 2/59 /content/datasets/Barcode-Detection--1/test/images/2-0006945032-0_jpeg.rf.8dd0e8309830d9901359cf13723c4716.jpg: 640x384 1 QR, 73.0ms
# image 3/59 /content/datasets/Barcode-Detection--1/test/images/2-0006949549-0_jpeg.rf.1957d34ad64105f15456a24553bcf2d6.jpg: 640x384 1 QR, 10.6ms
# image 4/59 /content/datasets/Barcode-Detection--1/test/images/2-0006953125-1_jpeg.rf.be226bb38f7519465873bdaca2d9b8bc.jpg: 480x640 1 QR, 70.2ms
# image 5/59 /content/datasets/Barcode-Detection--1/test/images/2-0006954989-1_jpeg.rf.9a6083902c52b146037df6d067f618a7.jpg: 640x384 1 QR, 11.3ms
# ...

# %% [markdown]
# # **Result**

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-009dea6711d2> in <cell line: 0>()
#       6
#       7 # List all directories that start with 'predict' in the base path
# ----> 8 subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
#       9               if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]
#      10
#
# NameError: name 'os' is not defined

# %% [markdown]
# # **Export** **ONNX**

# %%
# !pip install ultralytics --upgrade --force-reinstall


from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("/content/datasets/runs/detect/train2/weights/best.pt")

# Export the model to ONNX format
model.export(format="onnx")  # creates 'yolov8n.onnx'
# Out:
# ...
#   Using cached ultralytics-8.3.129-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# ...
#   Using cached PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ...
#   Using cached torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# ...

# %% [markdown]
# # **Download** **ONNX**

# %%
from google.colab import files

# Replace 'model.onnx' with the correct path to your exported model
files.download('/content/runs/detect/train/weights/best.onnx')
